# %%
import pickle

# open a file, where you stored the pickled data
file = open('tweets_features', 'rb')

# dump information to that file
feature_df = pickle.load(file)

# close the file
file.close()

# show dataframe with extracted features
print(feature_df)
# Out:
#        author                                 encoded_tweet_long  \
# 0   katyperry                                    [9, 20, 21, 22]
# 1   katyperry  [23, 10, 2, 11, 24, 25, 12, 26, 3, 2, 27, 28, 29]
# 2   katyperry                                           [30, 31]
# 3   katyperry                                       [32, 33, 34]
# 4   katyperry                            [13, 35, 36, 37, 2, 38]
# 5   katyperry           [14, 39, 40, 41, 42, 43, 44, 45, 15, 46]
# 6   katyperry                                           [47, 48]
# 7   katyperry                                           [50, 51]
# 8   katyperry                                    [52, 1, 53, 54]
# 9   katyperry                                               [13]
# 10  katyperry      [14, 55, 56, 16, 3, 57, 1, 58, 59, 15, 4, 60]
# 11  katyperry             [61, 62, 63, 1, 64, 65, 5, 66, 67, 68]
# 12  katyperry              [5, 69, 70, 71, 72, 6, 7, 73, 17, 74]
# ...
